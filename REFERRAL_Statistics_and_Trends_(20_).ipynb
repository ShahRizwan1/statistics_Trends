# %%
import pandas as pd

df = pd.read_csv("heart_failure_clinical_records.csv")

df.corr()
# Out:
#                                age   anaemia  creatinine_phosphokinase  \
# age                       1.000000  0.123102                 -0.064637
# anaemia                   0.123102  1.000000                 -0.181922
# creatinine_phosphokinase -0.064637 -0.181922                  1.000000
# diabetes                 -0.099938  0.002214                 -0.019987
# ejection_fraction         0.069380  0.023465                 -0.021007
# high_blood_pressure       0.092656  0.047172                 -0.045821
# platelets                -0.024959 -0.046343                  0.024809
# serum_creatinine          0.178194  0.032343                 -0.004032
# serum_sodium             -0.026182  0.020723                  0.051404
# sex                       0.072581 -0.081526                  0.069679
# smoking                   0.023534 -0.105996                 -0.014294
# time                     -0.220182 -0.111049                 -0.013789
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("heart_failure_clinical_records.csv")

def AgeHistogram():
  plt.figure(figsize=(10,6))
  plt.hist(df['age'], bins=10, color='skyblue', edgecolor='black')
  plt.title('Age Distribution')
  plt.xlabel('Age')
  plt.ylabel('Frequency')
  plt.grid(True)
  plt.show()

AgeHistogram()

def barchart():
  plt.figure(figsize=(10,6))
  df['DEATH_EVENT'].value_counts().plot(kind='bar', color=['skyblue', 'salmon'])
  plt.title('Count of Death Events')
  plt.xlabel('Death Events')
  plt.ylabel('Count')
  plt.xticks(ticks=[0,1], labels=['No', 'Yes'])
  plt.grid(axis='y')
  plt.show()

barchart()

def scatterplot():
  plt.figure(figsize=(10,6))
  plt.scatter(df['age'], df['serum_creatinine'], color='skyblue')
  plt.title('Serum Creatinine vs. age')
  plt.xlabel('Age')
  plt.ylabel('Serum Creatinine')
  plt.grid(True)
  plt.show()

scatterplot()

def boxplotFunc():
  plt.figure(figsize=(10,6))
  df.boxplot(column='ejection_fraction', by='high_blood_pressure', grid=False)
  plt.title("Ejection Fraction of high Blood Pressure")
  plt.xlabel('High Blood Pressure')
  plt.ylabel('Ejection Fraction')
  plt.suptitle('')
  plt.xticks(ticks=[1,2], labels = ['No', 'Yes'])
  plt.show()
boxplotFunc()

def heatmapG():
  plt.figure(figsize=(12, 8))
  corr_matrix = df.corr()
  sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths = 0.5)
  plt.title('Correlation Heatmap Matrix')
  plt.show()
heatmapG()
